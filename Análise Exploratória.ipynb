# %% [markdown]
# # Análise exploratória dados de projetos de lei
#
# Dados coletados em 20/10/2022 pelo dados abertos https://dadosabertos.camara.leg.br/swagger/api.html#staticfile
#
# ## Tipos de projetos estudados
# MPV - Medida Provisória
# PLV - Projeto de Lei de Conversão
# PDC - Projeto de Decreto Legislativo
# PRC - Projeto de Resolução
# INC - Indicação
# PL - Projeto de Lei

# %%
import pandas as pd

# %%
diretorio = "dados/cru"
df = pd.read_csv(diretorio + '/proposicoes-1998.csv', sep=';', index_col="id")
df
# Out:
#                                                        uri siglaTipo  numero  \
# id
# 12863    https://dadosabertos.camara.leg.br/api/v2/prop...       INC    1260
# 12881    https://dadosabertos.camara.leg.br/api/v2/prop...       INC    1277
# 12936    https://dadosabertos.camara.leg.br/api/v2/prop...       INC    1331
# 12938    https://dadosabertos.camara.leg.br/api/v2/prop...       INC    1332
# 12940    https://dadosabertos.camara.leg.br/api/v2/prop...       INC    1333
# ...                                                    ...       ...     ...
# 593911   https://dadosabertos.camara.leg.br/api/v2/prop...       EMS    4124
# 620597   https://dadosabertos.camara.leg.br/api/v2/prop...       MSG     268
# 2092098  https://dadosabertos.camara.leg.br/api/v2/prop...       EMR       1
# 2092099  https://dadosabertos.camara.leg.br/api/v2/prop...       PRL       1
# 2092100  https://dadosabertos.camara.leg.br/api/v2/prop...     EMC-A       1
#
# ...

# %%
# Out:
# Index(['id', 'uri', 'siglaTipo', 'numero', 'ano', 'codTipo', 'descricaoTipo',
#        'ementa', 'ementaDetalhada', 'keywords', 'dataApresentacao',
#        'uriOrgaoNumerador', 'uriPropAnterior', 'uriPropPrincipal',
#        'uriPropPosterior', 'urlInteiroTeor', 'urnFinal',
#        'ultimoStatus_dataHora', 'ultimoStatus_sequencia',
#        'ultimoStatus_uriRelator', 'ultimoStatus_idOrgao',
#        'ultimoStatus_siglaOrgao', 'ultimoStatus_uriOrgao',
#        'ultimoStatus_regime', 'ultimoStatus_descricaoTramitacao',
#        'ultimoStatus_idTipoTramitacao', 'ultimoStatus_descricaoSituacao',
#        'ultimoStatus_idSituacao', 'ultimoStatus_despacho', 'ultimoStatus_url'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19976 entries, 0 to 19975
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                19976 non-null  int64
#  1   uri                               19976 non-null  object
#  2   siglaTipo                         19976 non-null  object
#  3   numero                            19976 non-null  int64
#  4   ano                               19976 non-null  int64
#  5   codTipo                           19976 non-null  int64
#  6   descricaoTipo                     19976 non-null  object
#  7   ementa                            18794 non-null  object
#  8   ementaDetalhada                   164 non-null    object
#  9   keywords                          2664 non-null   object
#  10  dataApresentacao                  19976 non-null  object
# ...

# %%
temasdf = pd.read_csv('proposicoesTemas-2022.csv', sep=';')
temasdf
# Out:
#                                           uriProposicao siglaTipo  numero  \
# 0     https://dadosabertos.camara.leg.br/api/v2/prop...       INC       1
# 1     https://dadosabertos.camara.leg.br/api/v2/prop...       INC       1
# 2     https://dadosabertos.camara.leg.br/api/v2/prop...       INC       1
# 3     https://dadosabertos.camara.leg.br/api/v2/prop...       INC       1
# 4     https://dadosabertos.camara.leg.br/api/v2/prop...       PEC       1
# ...                                                 ...       ...     ...
# 6893  https://dadosabertos.camara.leg.br/api/v2/prop...        PL    2641
# 6894  https://dadosabertos.camara.leg.br/api/v2/prop...        PL    2644
# 6895  https://dadosabertos.camara.leg.br/api/v2/prop...        PL    2645
# 6896  https://dadosabertos.camara.leg.br/api/v2/prop...        PL    2646
# 6897  https://dadosabertos.camara.leg.br/api/v2/prop...        PL    2646
#
#        ano  codTema                                         tema  relevancia
# ...

# %%
autoresdf = pd.read_csv('proposicoesAutores-2022.csv', sep=';')
grouped = autoresdf.groupby('idProposicao').count()
grouped
# Out:
#               uriProposicao  idDeputadoAutor  uriAutor  codTipoAutor  \
# idProposicao
# 303153                    1                1         1             1
# 587207                    1                1         1             1
# 996806                    1                1         1             1
# 2053152                   1                1         1             1
# 2311331                   1                1         1             1
# ...                     ...              ...       ...           ...
# 2336065                   1                0         1             1
# 2336066                   1                0         1             1
# 2336067                   1                1         1             1
# 2336068                   1                0         1             1
# 2336069                   1                1         1             1
#
#               tipoAutor  nomeAutor  siglaPartidoAutor  uriPartidoAutor  \
# idProposicao
# ...
